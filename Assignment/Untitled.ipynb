# %%
import pandas as pd
from translate_pdf_word import Word2word
# substitute "your path/to/word.docx" with your word file name or path to it
word = Word2word.Word2word("word.docx")
word.translate_all_in_one_shot()
word.save2docx()
